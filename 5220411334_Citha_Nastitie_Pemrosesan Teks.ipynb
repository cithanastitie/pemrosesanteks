# %%
# !pip install google_play_scraper

# %%
from google_play_scraper import Sort, reviews
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
# Mulai Scraping
result, continuation_token = reviews(
    'com.grabtaxi.passenger',
    lang='id', # bahasa
    country='id', # negara
    sort=Sort.NEWEST, # sorting yang paling relevan/baru
    count=1000, # jumlah dataset
    filter_score_with=None
)

# %%
# Membuat Dataframe dari hasil scraping 5 data teratas
data = pd.DataFrame(np.array(result),columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))
data.head()
# Out:
#                                reviewId             userName  \
# 0  8418759a-0af6-489e-a55b-bbaab2dde480           Rezi Aryan
# 1  2ebd46da-6540-4913-a341-af21a4389087              Intan D
# 2  c590421a-bf9a-486b-9486-133831a6a93c  Shinta Widyaningrum
# 3  56fbca8e-9d0f-47a9-9127-491eb101409a     Rangga Cok Kolok
# 4  df522393-dedc-44e0-a298-7295b7753292        ARFI MUHAMMAD
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  driver ga ada yg punya etitud bagus, makanan d...      1              0
# 1              ongkirnya jangan mahal mahal napa 😭😭😭      4              0
# ...

# %%
# Membuat Dataframe dari hasil scraping 5 data terakhir
data = pd.DataFrame(np.array(result),columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))
data.tail()
# Out:
#                                  reviewId                  userName  \
# 995  dc2114d0-ca98-4d65-89d9-c17d0abeaf37                  Anggi Fc
# 996  617f3166-7ee3-46d2-8ef2-fa5d1ae43007                D Duherman
# 997  08dcfefd-c546-448d-acd1-fd6befee47cc                       Via
# 998  4b04adba-abdc-486b-a06e-74290dd9b0a9  Emmanuel Jonathan Robert
# 999  9b499913-44b3-4a52-9c96-e4672d310f0e               Eko Nugroho
#
#                                              userImage  \
# 995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 996  https://play-lh.googleusercontent.com/a-/ALV-U...
# 997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                content  score  thumbsUpCount  \
# 995                                            terbaik      5              0
# ...

# %%
len(data)
# Out:
# 1000

# %%
data['content_casefold'] = data['content'].astype(str).str.lower()
data['replyContent_casefold'] = data['replyContent'].astype(str).str.lower()

# %%
data.head()
# Out:
#                                reviewId             userName  \
# 0  8418759a-0af6-489e-a55b-bbaab2dde480           Rezi Aryan
# 1  2ebd46da-6540-4913-a341-af21a4389087              Intan D
# 2  c590421a-bf9a-486b-9486-133831a6a93c  Shinta Widyaningrum
# 3  56fbca8e-9d0f-47a9-9127-491eb101409a     Rangga Cok Kolok
# 4  df522393-dedc-44e0-a298-7295b7753292        ARFI MUHAMMAD
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  driver ga ada yg punya etitud bagus, makanan d...      1              0
# 1              ongkirnya jangan mahal mahal napa 😭😭😭      4              0
# ...

# %%
data.to_csv('Scrpaing Grab.csv', index=False, encoding='utf=8')
